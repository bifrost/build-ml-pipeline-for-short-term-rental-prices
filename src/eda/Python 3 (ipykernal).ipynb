# %%
# !conda list env
# Out:
# # packages in environment at /Users/dan/opt/miniconda3/envs/udacity:
# #
# # Name                    Version                   Build  Channel

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- -----------
# alembic                   1.4.1
# antlr4-python3-runtime    4.9.3
# anyio                     3.5.0
# appdirs                   1.4.4
# appnope                   0.1.2
# argon2-cffi               21.3.0
# argon2-cffi-bindings      21.2.0
# astroid                   2.13.3
# asttokens                 2.0.5
# attrs                     22.1.0
# autopep8                  1.6.0
# Babel                     2.11.0
# backcall                  0.2.0
# bcrypt                    3.2.2
# beautifulsoup4            4.11.1
# bleach                    4.1.0
# blinker                   1.5
# botocore                  1.27.2
# Bottleneck                1.3.5
# brotlipy                  0.7.0
# certifi                   2022.12.7
# cffi                      1.15.1
# charset-normalizer        2.0.4
# click                     8.0.4
# cloudpickle               2.2.1
# colorama                  0.4.4
# ...
